# %%
import numpy as np
import import_ipynb



class IoTDeviceParams:
    def __init__(self, position=(0, 0), color='blue', data=15.0):
        self.position = position # Device의 좌표들!!!!!
        self.data = data
        self.color = color


class IoTDevice:
    data: float
    collected_data: float
    new_data: float

    # data_timeseries = []
    # data_rate_timeseries = []

    def __init__(self, params: IoTDeviceParams):
        self.params = params


        self.position = params.position       #  self.position (13, 5)  self.position (27, 17)  self.position (9, 26)
        self.color = params.color
        self.data = params.data
        #print('self.data', self.data)
        # self.data_timeseries = [self.data]
        # self.data_rate_timeseries = [0]
        self.collected_data = 0
        self.new_data = 0
        
    def collect_data(self):
        self.data -= 5.0
        remaining_data = self.data

        # return collection ratio, i.e. the percentage of time used for comm
        return remaining_data
    
    def new(self):
        a = np.random.poisson(0.05)
        self.new_data += a
        
        return a

    @property
    def depleted(self):
        return self.data <= self.collected_data
    
    def tours_position(self):
        return self.position


class DeviceList: #DeviceList로 디바이스들의 좌표, 데이터 등 정해서 self.devices로 넣는 것 같은데

    def __init__(self, params):
        self.devices = [IoTDevice(device) for device in params]
     
    def collect_data(self, tour_point, index):
        if index == 2: #self.state.tour_counter == [32]
            if tour_point == (3, 5):
                idxs = 0
            elif tour_point == (4, 5):
                idxs = 1
            elif tour_point == (5, 5):
                idxs = 2            
            elif tour_point == (6, 5):
                idxs = 3 
            elif tour_point == (6, 4):
                idxs = 4
            elif tour_point == (6, 3):
                idxs = 5            
            elif tour_point == (7, 3):
                idxs = 6  
            elif tour_point == (7, 2):
                idxs = 7
            elif tour_point == (8, 2):
                idxs = 8            
            elif tour_point == (8, 1):
                idxs = 9 
            elif tour_point == (9, 1):
                idxs = 10
            elif tour_point == (10, 1):
                idxs = 11           
            elif tour_point == (11, 1):
                idxs = 12      
            elif tour_point == (11, 2):
                idxs = 13  
            elif tour_point == (12, 2):
                idxs = 14
            elif tour_point == (12, 3):
                idxs = 15            
            elif tour_point == (13, 3):
                idxs = 16 
            elif tour_point == (14, 3):
                idxs = 17
            elif tour_point == (14, 4):
                idxs = 18           
            elif tour_point == (15, 4):
                idxs = 19   
            elif tour_point == (15, 5):
                idxs = 20
            elif tour_point == (16, 5):
                idxs = 21           
            elif tour_point == (17, 5):
                idxs = 22      
            elif tour_point == (18, 5):
                idxs = 23  
            elif tour_point == (18, 6):
                idxs = 24
            elif tour_point == (19, 6):
                idxs = 25            
            elif tour_point == (20, 6):
                idxs = 26 
            elif tour_point == (20, 7):
                idxs = 27
            elif tour_point == (21, 7):
                idxs = 28           
            elif tour_point == (22, 7):
                idxs = 29   
            elif tour_point == (23, 7):
                idxs = 30  
            elif tour_point == (10, 8):
                idxs = 31
            elif tour_point == (14, 11):
                idxs = 32  
        if index == 1:   #self.state.tour_counter == [26]
            if tour_point == (10, 9):
                idxs = 0
            elif tour_point == (11, 11):
                idxs = 1
            elif tour_point == (11, 14):
                idxs = 2           
            elif tour_point == (14, 14):
                idxs = 3   
            elif tour_point == (15, 12):
                idxs = 4
            elif tour_point == (16, 12):
                idxs = 5           
            elif tour_point == (17, 12):
                idxs = 6      
            elif tour_point == (17, 13):
                idxs = 7  
            elif tour_point == (18, 13):
                idxs = 8
            elif tour_point == (18, 14):
                idxs = 9            
            elif tour_point == (19, 14):
                idxs = 10 
            elif tour_point == (20, 14):
                idxs = 11
            elif tour_point == (21, 14):
                idxs = 12           
            elif tour_point == (21, 13):
                idxs = 13 
            elif tour_point == (22, 13):
                idxs = 14      
            elif tour_point == (22, 12):
                idxs = 15  
            elif tour_point == (22, 11):
                idxs = 16
            elif tour_point == (22, 10):
                idxs = 17            
            elif tour_point == (23, 10):
                idxs = 18 
            elif tour_point == (23, 9):
                idxs = 19
            elif tour_point == (24, 9):
                idxs = 20           
            elif tour_point == (14, 26):
                idxs = 21      ###
            elif tour_point == (27, 7):
                idxs = 22            
            elif tour_point == (28, 7):
                idxs = 23 
            elif tour_point == (27, 8):
                idxs = 24
            elif tour_point == (28, 8):
                idxs = 25           
            elif tour_point == (31, 7):
                idxs = 26
                ####
        else:
            if tour_point == (3, 5):
                idxs = 0
            elif tour_point == (4, 5):
                idxs = 1
            elif tour_point == (5, 5):
                idxs = 2            
            elif tour_point == (6, 5):
                idxs = 3 
            elif tour_point == (6, 4):
                idxs = 4
            elif tour_point == (6, 3):
                idxs = 5            
            elif tour_point == (7, 3):
                idxs = 6  
            elif tour_point == (7, 2):
                idxs = 7
            elif tour_point == (8, 2):
                idxs = 8            
            elif tour_point == (8, 1):
                idxs = 9 
            elif tour_point == (9, 1):
                idxs = 10
            elif tour_point == (10, 1):
                idxs = 11           
            elif tour_point == (11, 1):
                idxs = 12      
            elif tour_point == (11, 2):
                idxs = 13  
            elif tour_point == (12, 2):
                idxs = 14
            elif tour_point == (12, 3):
                idxs = 15            
            elif tour_point == (13, 3):
                idxs = 16 
            elif tour_point == (14, 3):
                idxs = 17
            elif tour_point == (14, 4):
                idxs = 18           
            elif tour_point == (15, 4):
                idxs = 19   
            elif tour_point == (15, 5):
                idxs = 20
            elif tour_point == (16, 5):
                idxs = 21           
            elif tour_point == (17, 5):
                idxs = 22      
            elif tour_point == (18, 5):
                idxs = 23  
            elif tour_point == (18, 6):
                idxs = 24
            elif tour_point == (19, 6):
                idxs = 25            
            elif tour_point == (20, 6):
                idxs = 26 
            elif tour_point == (20, 7):
                idxs = 27
            elif tour_point == (21, 7):
                idxs = 28           
            elif tour_point == (22, 7):
                idxs = 29   
            elif tour_point == (23, 7):
                idxs = 30  
            elif tour_point == (10, 8):
                idxs = 31
            elif tour_point == (14, 11):
                idxs = 32            
############################################################################
            elif tour_point == (10, 9):
                idxs = 33 
            elif tour_point == (11, 11):
                idxs = 34
            elif tour_point == (11, 14):
                idxs = 35           
            elif tour_point == (14, 14):
                idxs = 36  
            elif tour_point == (15, 12):
                idxs = 37
            elif tour_point == (16, 12):
                idxs = 38          
            elif tour_point == (17, 12):
                idxs = 39     
            elif tour_point == (17, 13):
                idxs = 40 
            elif tour_point == (18, 13):
                idxs = 41
            elif tour_point == (18, 14):
                idxs = 42            
            elif tour_point == (19, 14):
                idxs = 43 
            elif tour_point == (20, 14):
                idxs = 44
            elif tour_point == (21, 14):
                idxs = 45           
            elif tour_point == (21, 13):
                idxs = 46 
            elif tour_point == (22, 13):
                idxs = 47      
            elif tour_point == (22, 12):
                idxs = 48  
            elif tour_point == (22, 11):
                idxs = 49
            elif tour_point == (22, 10):
                idxs = 50            
            elif tour_point == (23, 10):
                idxs = 51 
            elif tour_point == (23, 9):
                idxs = 52
            elif tour_point == (24, 9):
                idxs = 53           
            elif tour_point == (14, 26):
                idxs = 54      ###
            elif tour_point == (27, 7):
                idxs = 55            
            elif tour_point == (28, 7):
                idxs = 56 
            elif tour_point == (27, 8):
                idxs = 57
            elif tour_point == (28, 8):
                idxs = 58           
            elif tour_point == (31, 7):
                idxs = 59
                           
        self.devices[idxs].collect_data() # -= 5.0씩 데이터 변화 
        if self.devices[idxs].data == 0.0:
            return True
            
        return False    

            
                   
    def get_position(self):
        position_list = []
        for device in self.devices:
            position_list.append(device.tours_position())
  
        return position_list    
        

    def get_data_map(self, shape): #남은 data 표현
        data_map = np.zeros(shape, dtype=float)

        
        for device in self.devices:
            data_map[device.position[1], device.position[0]] = device.data - device.collected_data + device.new_data
         #   print("collected :", device.collected_data, 
         #       "new:", device.new_data
         #     )
            
        return data_map

    def get_collected_map(self, shape):
        data_map = np.zeros(shape, dtype=float)

        for device in self.devices:
            data_map[device.position[1], device.position[0]] = device.collected_data

        return data_map

    def new_data(self):
        for device in self.devices:
            added_data = device.new()

        return added_data

    def get_devices(self):
        return self.devices

    def get_device(self, idx):
        return self.devices[idx]

    def get_total_data(self):
        return sum(list([device.data + device.new_data for device in self.devices]))

    def get_collected_data(self):
        return sum(list([device.collected_data for device in self.devices]))
        
    @property
    def num_devices(self):
        return len(self.devices)

# %%
# Out:
# 3
# True
