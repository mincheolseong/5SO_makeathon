# %%
import argparse
import os

import import_ipynb
from MainEnvironment import EnvironmentParams, Environment

from Utils import *

if __name__ == "__main__":

    parser = argparse.ArgumentParser()
    parser.add_argument('--gpu', action='store_true', help='Activates usage of GPU')
    parser.add_argument('--generate_config', action='store_true', help='Enable to write default config only')
    #parser.add_argument('--config', default=None, help='Path to config file')
    parser.add_argument('--config', default='config/grid_image.json', help='Path to config file')
    parser.add_argument('--id', default='grid_image', help='Overrides the logfile name and the save name')

    #args = parser.parse_args()
    args = parser.parse_args(args=[])

    if args.generate_config:
        generate_config(EnvironmentParams(), "config/default.json")
        exit(0)

    if args.config is None:
        print("Config file needed!")
        exit(1)

    if not args.gpu:
        os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

    params = read_config(args.config)

    if args.id is not None:
        params.model_stats_params.save_model = "models/" + args.id
        params.model_stats_params.log_file_name = args.id

    env = Environment(params)

    env.run()
# Out:
# importing Jupyter notebook from MainEnvironment.ipynb
# importing Jupyter notebook from Agent.ipynb
# importing Jupyter notebook from Trainer.ipynb
# importing Jupyter notebook from ReplayMemory.ipynb
# importing Jupyter notebook from Display.ipynb
# importing Jupyter notebook from Map.ipynb
# importing Jupyter notebook from BaseDisplay.ipynb
# importing Jupyter notebook from Grid.ipynb
# importing Jupyter notebook from DeviceManager.ipynb
# importing Jupyter notebook from IoTDevice.ipynb
# importing Jupyter notebook from Channel.ipynb
# importing Jupyter notebook from Shadowing.ipynb
# importing Jupyter notebook from State.ipynb
# importing Jupyter notebook from StateUtils.ipynb
# importing Jupyter notebook from BaseState.ipynb
# importing Jupyter notebook from BaseGrid.ipynb
# importing Jupyter notebook from ModelStats.ipynb
# importing Jupyter notebook from Physics.ipynb
# importing Jupyter notebook from GridActions.ipynb
# importing Jupyter notebook from GridPhysics.ipynb
# importing Jupyter notebook from Rewards.ipynb
# importing Jupyter notebook from GridRewards.ipynb
# importing Jupyter notebook from Environment.ipynb
# importing Jupyter notebook from Utils.ipynb
# Parse Params file here from  config/grid_image.json  and pass into main
# logs/training/grid_image already exists.
# Override log file? [Y/n]
# 1
# Deleting old log dir
# [(125, 65), (126, 65), (127, 65), (128, 65), (129, 65), (130, 65), (131, 65), (132, 65), (133, 65), (134, 65), (125, 66), (126, 66), (127, 66), (128, 66), (129, 66), (130, 66), (131, 66), (132, 66), (133, 66), (134, 66), (125, 67), (126, 67), (127, 67), (128, 67), (129, 67), (130, 67), (131, 67), (132, 67), (133, 67), (134, 67), (125, 68), (126, 68), (127, 68), (128, 68), (129, 68), (130, 68), (131, 68), (132, 68), (133, 68), (134, 68), (125, 69), (126, 69), (127, 69), (128, 69), (129, 69), (130, 69), (131, 69), (132, 69), (133, 69), (134, 69), (125, 70), (126, 70), (127, 70), (128, 70), (129, 70), (130, 70), (131, 70), (132, 70), (133, 70), (134, 70), (125, 71), (126, 71), (127, 71), (128, 71), (129, 71), (130, 71), (131, 71), (132, 71), (133, 71), (134, 71), (125, 72), (126, 72), (127, 72), (128, 72), (129, 72), (130, 72), (131, 72), (132, 72), (133, 72), (134, 72), (125, 73), (126, 73), (127, 73), (128, 73), (129, 73), (130, 73), (131, 73), (132, 73), (133, 73), (134, 73), (125, 74), (126, 74), (127, 74), (128, 74), (129, 74), (130, 74), (131, 74), (132, 74), (133, 74), (134, 74), (126, 75), (127, 75), (128, 75), (129, 75), (130, 75), (131, 75), (132, 75), (133, 75), (134, 75)]
#   0%|                                                                                      | 0/25000.0 [00:00<?, ?it/s]
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# boolean_map_input (InputLayer)  [(None, 174, 174, 4) 0
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 174, 174, 4)  0           boolean_map_input[0][0]
# __________________________________________________________________________________________________
# float_map_input (InputLayer)    [(None, 174, 174, 2) 0
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 174, 174, 6)  0           tf.cast[0][0]
#                                                                  float_map_input[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 58, 58, 6)    0           tf.concat[0][0]
# __________________________________________________________________________________________________
# tf.image.central_crop (TFOpLamb (None, 18, 18, 6)    0           tf.concat[0][0]
# __________________________________________________________________________________________________
# tf.stop_gradient (TFOpLambda)   (None, 58, 58, 6)    0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# tf.stop_gradient_1 (TFOpLambda) (None, 18, 18, 6)    0           tf.image.central_crop[0][0]
# __________________________________________________________________________________________________
# global_conv_1 (Conv2D)          (None, 54, 54, 16)   2416        tf.stop_gradient[0][0]
# __________________________________________________________________________________________________
# local_conv_1 (Conv2D)           (None, 14, 14, 16)   2416        tf.stop_gradient_1[0][0]
# __________________________________________________________________________________________________
# global_conv_2 (Conv2D)          (None, 50, 50, 16)   6416        global_conv_1[0][0]
# __________________________________________________________________________________________________
# local_conv_2 (Conv2D)           (None, 10, 10, 16)   6416        local_conv_1[0][0]
# __________________________________________________________________________________________________
# global_flatten (Flatten)        (None, 40000)        0           global_conv_2[0][0]
# __________________________________________________________________________________________________
# local_flatten (Flatten)         (None, 1600)         0           local_conv_2[0][0]
# __________________________________________________________________________________________________
# concat_flatten (Concatenate)    (None, 41600)        0           global_flatten[0][0]
#                                                                  local_flatten[0][0]
# __________________________________________________________________________________________________
# scalars_input (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# termination_input (InputLayer)  [(None,)]            0
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 41601)        0           concat_flatten[0][0]
#                                                                  scalars_input[0][0]
# __________________________________________________________________________________________________
# tf.math.logical_not (TFOpLambda (None,)              0           termination_input[0][0]
# __________________________________________________________________________________________________
# hidden_layer_all_0 (Dense)      (None, 256)          10650112    concat[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          (None,)              0           tf.math.logical_not[0][0]
# __________________________________________________________________________________________________
# hidden_layer_all_1 (Dense)      (None, 256)          65792       hidden_layer_all_0[0][0]
# __________________________________________________________________________________________________
# q_star_input (InputLayer)       [(None,)]            0
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None,)              0           tf.cast_1[0][0]
# __________________________________________________________________________________________________
# hidden_layer_all_2 (Dense)      (None, 256)          65792       hidden_layer_all_1[0][0]
# __________________________________________________________________________________________________
# reward_input (InputLayer)       [(None,)]            0
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None,)              0           q_star_input[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# action_input (InputLayer)       [(None,)]            0
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 6)            1542        hidden_layer_all_2[0][0]
# __________________________________________________________________________________________________
# tf.math.add (TFOpLambda)        (None,)              0           reward_input[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.one_hot_2 (TFOpLambda)       (None, 6)            0           action_input[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1)            0           tf.math.add[0][0]
# __________________________________________________________________________________________________
# tf.one_hot_1 (TFOpLambda)       (None, 6)            0           action_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 6)            0           output_layer[0][0]
#                                                                  tf.one_hot_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 6)            0           tf.expand_dims[0][0]
#                                                                  tf.one_hot_1[0][0]
# __________________________________________________________________________________________________
# tf.stop_gradient_4 (TFOpLambda) (None, 6)            0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.add_1 (TFOpLambda)      (None, 6)            0           tf.math.multiply_4[0][0]
#                                                                  tf.stop_gradient_4[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 6)            0           output_layer[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_1 (TFOpLam (None, 6)            0           tf.math.add_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_2 (TFOpLam (None, 6)            0           tf.convert_to_tensor[0][0]
# __________________________________________________________________________________________________
# tf.cast_2 (TFOpLambda)          (None, 6)            0           tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference (TFO (None, 6)            0           tf.convert_to_tensor_2[0][0]
#                                                                  tf.cast_2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None,)              0           tf.math.squared_difference[0][0]
# __________________________________________________________________________________________________
# tf.cast_3 (TFOpLambda)          (None,)              0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None,)              0           tf.cast_3[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd ()                   0           tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size (TFOpLambda)  ()                   0           tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_2 (TFOpLambd ()                   0           tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# tf.cast_4 (TFOpLambda)          ()                   0           tf.compat.v1.size[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan (TFOpLamb ()                   0           tf.math.reduce_sum_2[0][0]
#                                                                  tf.cast_4[0][0]
# __________________________________________________________________________________________________
# tf.cast_5 (TFOpLambda)          ()                   0           tf.math.divide_no_nan[0][0]
# ==================================================================================================
# Total params: 10,800,902
# Trainable params: 10,800,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Filling replay memory
#  35%|██████████████████████████▏                                                | 8747/25000.0 [01:41<05:56, 45.55it/s]

# %%
#그 전에, Trainer의 rm_size을 50,000에서 25,000으로 줄여봄 -> 커널 얘만 틀고
#import tensorflow as tf
#config = tf.compat.v1.ConfigProto()
#config.gpu_options.allow_growth = True
#session = tf.compat.v1.Session(config=config)
#실행시 메모리 문제 해결!! 흠,, 근데 rm_size = 50,000에서는 여전히 메모리 문제가 발생해서 45,000으로 계속 진행
